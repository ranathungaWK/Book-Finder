# %%
# !nvidia-smi
# Out:
# Wed Nov  5 13:17:26 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8              9W /   70W |       2MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics

# %%
import torch
print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("GPU name:", torch.cuda.get_device_name(0))
# Out:
# Torch version: 2.8.0+cu126
# CUDA available: True
# GPU name: Tesla T4

# %%
# !ls /content/Book-Finder/finetune
# Out:
# ls: cannot access '/content/Book-Finder/finetune': No such file or directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/finetune
# !ls
# Out:
# /content/drive/MyDrive/finetune
# 'Book spine instance segmentation.v1i.yolov8.zip'   runs    yolo11n.pt
#  data.yaml					    test    yolov8n.pt
#  README.dataset.txt				    train   yolov8s.pt
#  README.roboflow.txt				    valid

# %%
# !pip install -U ultralytics

# %%
# !yolo detect train \
  data=data.yaml \
  model=yolov8n.pt \
  epochs=50 \
  imgsz=416 \
  batch=8 \
  device=0
# Out:
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo detect predict \
  model=/content/drive/MyDrive/finetune/runs/detect/train2/weights/best.pt \
  source=/content/drive/MyDrive/finetune/test/images \
  save=True
# Out:
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/153 /content/drive/MyDrive/finetune/test/images/FullSizeRender-2_JPEG_jpg.rf.b0b0ccf9a4df205fae247402aca05a68.jpg: 416x416 17 book spines, 8.2ms
# image 2/153 /content/drive/MyDrive/finetune/test/images/IMG_4773_JPEG_jpg.rf.16943b6217dc384e4ea8231ffec81729.jpg: 416x416 23 book spines, 7.8ms
# image 3/153 /content/drive/MyDrive/finetune/test/images/IMG_4776_JPEG_jpg.rf.87216aff677ab281b7baee61e03fe7df.jpg: 416x416 27 book spines, 6.6ms
# image 4/153 /content/drive/MyDrive/finetune/test/images/IMG_4783_JPEG_jpg.rf.f9fd00060c1faebc4c25e49424a9d7d5.jpg: 416x416 28 book spines, 7.9ms
# image 5/153 /content/drive/MyDrive/finetune/test/images/IMG_4793_JPEG_jpg.rf.2cd21d4d81e31ded87ea826d724dabb1.jpg: 416x416 23 book spines, 7.2ms
# ...

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/finetune/runs/detect/train/weights/best.pt")
metrics = model.val(data="/content/drive/MyDrive/finetune/data.yaml")

print(metrics)
# Out:
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.6±0.4 ms, read: 5.8±4.3 MB/s, size: 18.6 KB)
# val: Scanning /content/drive/MyDrive/finetune/valid/labels.cache... 293 images, 9 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 293/293 83.9Kit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 4536, len(boxes) = 4719. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 3.5it/s 5.4s
#                    all        293       4719      0.955      0.912      0.966      0.813
# Speed: 1.0ms preprocess, 5.4ms inference, 0.0ms loss, 2.5ms postprocess per image
# ...
